# %% [markdown]
# # Movie Recommendation System

# %% [markdown]
# ![img](images/Movies.png)

# %% [markdown]
# 1. Importing the necessary libraries:

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import ipywidgets as widgets
from IPython.display import display
import os

# %% [markdown]
# 2. Reading movie data from a CSV file into a pandas DataFrame:

# %%
movies = pd.read_csv("data/movies.csv")

# %%
movies
# Out:
#        movieId                               title
# 0            1                    Toy Story (1995)  \
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %% [markdown]
# 3. Extracting the year from the movie titles using regular expressions:

# %%
movies['year'] = movies['title'].str.extract(r'\((\d{4})\)')

# %% [markdown]
# 4. Converting the extracted year to numeric format:

# %%
movies['year'] = pd.to_numeric(movies['year'])

# %% [markdown]
# 5. Finding the oldest and most recent years in the dataset:

# %%
oldest_year = movies['year'].min()
most_recent_year = movies['year'].max()

# %%
print("Oldest Year:", oldest_year)
print("Most Recent Year:", most_recent_year)
# Out:
# Oldest Year: 1874.0
# Most Recent Year: 2019.0

# %% [markdown]
# 6. Defining a function to clean movie titles by removing special characters:

# %%
def clean_title(title):
    title = re.sub("[^a-zA-Z0-9 ]", "", title)
    return title

# %% [markdown]
# 7. Applying the clean_title function to the "title" column of the movies DataFrame and storing the cleaned titles in a new column called "clean_title":

# %%
movies["clean_title"] = movies["title"].apply(clean_title)

# %%
movies
# Out:
#        movieId                               title
# 0            1                    Toy Story (1995)  \
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres    year
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995.0  \
# 1                       Adventure|Children|Fantasy  1995.0
# 2                                   Comedy|Romance  1995.0
# 3                             Comedy|Drama|Romance  1995.0
# 4                                           Comedy  1995.0
# ...                                            ...     ...
# 62418                                        Drama  2018.0
# 62419                                  Documentary  2001.0
# 62420                                 Comedy|Drama  2018.0
# 62421                           (no genres listed)  2001.0
# 62422                       Action|Adventure|Drama  1962.0
#
#                             clean_title
# 0                        Toy Story 1995
# 1                          Jumanji 1995
# 2                 Grumpier Old Men 1995
# 3                Waiting to Exhale 1995
# 4      Father of the Bride Part II 1995
# ...                                 ...
# 62418                           We 2018
# 62419           Window of the Soul 2001
# 62420                    Bad Poems 2018
# 62421                 A Girl Thing 2001
# 62422       Women of Devils Island 1962
#
# [62423 rows x 5 columns]

# %% [markdown]
# 8. Creating an instance of the TfidfVectorizer class with an n-gram range of (1,2) to consider both single words and bigrams as features:

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2))

# %% [markdown]
# 9. Transforming the "clean_title" column of the movies DataFrame into a TF-IDF matrix using the fitted TfidfVectorizer:

# %%
tfidf = vectorizer.fit_transform(movies["clean_title"])
tfidf
# Out:
# <62423x170073 sparse matrix of type '<class 'numpy.float64'>'
# 	with 446566 stored elements in Compressed Sparse Row format>

# %% [markdown]
# 10. Defining a function to search for similar movies based on a given title:

# %%
def search(title):
    title = clean_title(title)
    query_vec = vectorizer.transform([title])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]
    results = movies.iloc[indices].iloc[::-1]
    return results

# %% [markdown]
# 11. Creating an input widget for the user to enter a movie title:

# %%
movie_input = widgets.Text(
    placeholder='Input Movie',
    description='Movie Title:',
    disabled=False
)

# %% [markdown]
# 12. Creating an output widget to display the search results:

# %%
movie_list = widgets.Output()

# %% [markdown]
# 13. Defining a callback function that is triggered when the user types in the movie input widget:

# %%
def on_type(data):
    with movie_list:
        movie_list.clear_output()
        title = data["new"]
        if len(title) > 0:
            display(search(title))
            

# Observing changes in the value of the movie input widget and calling the on_type function:
movie_input.observe(on_type, names='value') 

# Displaying the movie input widget and the movie list widget:
display(movie_input, movie_list)
# Out:
# Text(value='', description='Movie Title:', placeholder='Input Movie')
# Output()

# %% [markdown]
# 14. Accessing a specific movie by its movie ID:

# %%
movie_id = 89745
movie = movies[movies["movieId"] == movie_id]

# %% [markdown]
# 15. Reading ratings data from a CSV file into a pandas DataFrame:

# %%
ratings = pd.read_csv("data/ratings.csv")

# %%
ratings = ratings.drop('timestamp', axis=1)

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1      296     5.0
# 1              1      306     3.5
# 2              1      307     5.0
# 3              1      665     5.0
# 4              1      899     3.5
# ...          ...      ...     ...
# 25000090  162541    50872     4.5
# 25000091  162541    55768     2.5
# 25000092  162541    56176     2.0
# 25000093  162541    58559     4.0
# 25000094  162541    63876     5.0
#
# [25000095 rows x 3 columns]

# %% [markdown]
# 16. Selecting the unique user IDs who rated the specific movie with a rating higher than 4:

# %%
similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] > 4)]["userId"].unique()
similar_users
# Out:
# array([    21,    187,    208, ..., 162469, 162485, 162532])

# %% [markdown]
# 17. Finding movies that were highly rated by the similar users and calculating their frequency in perecentage:

# %%
similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]
similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
similar_user_recs
# Out:
# movieId
# 89745     1.000000
# 58559     0.573393
# 59315     0.530649
# 79132     0.519715
# 2571      0.496687
#             ...
# 160402    0.000166
# 161642    0.000166
# 158950    0.000166
# 199648    0.000166
# 198609    0.000166
# Name: count, Length: 16553, dtype: float64

# %% [markdown]
# 18. Filtering the recommended movies based on a threshold (0.10 in this case)This means that only movies that were rated highly by at least 10% of similar users will be considered:

# %%
similar_user_recs = similar_user_recs[similar_user_recs > .10]
similar_user_recs
# Out:
# movieId
# 89745    1.000000
# 58559    0.573393
# 59315    0.530649
# 79132    0.519715
# 2571     0.496687
#            ...
# 47610    0.103545
# 780      0.103380
# 88744    0.103048
# 1258     0.101226
# 1193     0.100895
# Name: count, Length: 193, dtype: float64

# %% [markdown]
# 19. Selecting all users who rated the recommended movies:

# %%
all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
all_users
# Out:
#           userId  movieId  rating
# 0              1      296     5.0
# 29             1     4973     4.5
# 48             1     7361     5.0
# 72             2      110     5.0
# 76             2      260     5.0
# ...          ...      ...     ...
# 25000065  162541     5952     5.0
# 25000078  162541     7153     5.0
# 25000081  162541     7361     4.5
# 25000086  162541    31658     4.5
# 25000090  162541    50872     4.5
#
# [1893092 rows x 3 columns]

# %% [markdown]
# 20. Calculating the frequency of the recommended movies among all users: will contain the IDs of the movies and their relative frequency among all users.

# %%
all_user_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())
all_user_recs
# Out:
# movieId
# 318       0.346395
# 296       0.288146
# 2571      0.247010
# 356       0.238136
# 593       0.228665
#             ...
# 86332     0.010142
# 91630     0.009324
# 122900    0.008573
# 122926    0.008070
# 106072    0.005289
# Name: count, Length: 193, dtype: float64

# %% [markdown]
# 21. Concatenating the similar user recommendations and all user recommendations into a DataFrame:

# %%
rec_percentages = pd.concat([similar_user_recs, all_user_recs], axis=1)
rec_percentages.columns = ["similar", "all"]

# %%
rec_percentages
# Out:
#           similar       all
# movieId
# 89745    1.000000  0.040459
# 58559    0.573393  0.148256
# 59315    0.530649  0.054931
# 79132    0.519715  0.132987
# 2571     0.496687  0.247010
# ...           ...       ...
# 47610    0.103545  0.022770
# 780      0.103380  0.054723
# 88744    0.103048  0.010383
# 1258     0.101226  0.083887
# 1193     0.100895  0.120244
#
# [193 rows x 2 columns]

# %% [markdown]
# 22. Calculating a score for each recommended movie by dividing the similar user recommendations by the all user recommendations:

# %%
rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
rec_percentages["score"]
# Out:
# movieId
# 89745    24.716368
# 58559     3.867590
# 59315     9.660345
# 79132     3.908027
# 2571      2.010791
#            ...
# 47610     4.547463
# 780       1.889149
# 88744     9.924843
# 1258      1.206688
# 1193      0.839081
# Name: score, Length: 193, dtype: float64

# %% [markdown]
# 23. Sorting the recommended movies by the score in descending order:

# %%
rec_percentages = rec_percentages.sort_values("score", ascending=False)
rec_percentages
# Out:
#           similar       all      score
# movieId
# 89745    1.000000  0.040459  24.716368
# 106072   0.103711  0.005289  19.610199
# 122892   0.241054  0.012367  19.491770
# 102125   0.216534  0.012119  17.867419
# 88140    0.215043  0.012052  17.843074
# ...           ...       ...        ...
# 296      0.288933  0.288146   1.002730
# 593      0.222830  0.228665   0.974483
# 527      0.199967  0.217833   0.917984
# 1193     0.100895  0.120244   0.839081
# 2858     0.139993  0.169679   0.825051
#
# [193 rows x 3 columns]

# %% [markdown]
# 24. Displaying the top 10 recommended movies merged with the movie details:

# %%
rec_percentages.merge(movies, left_index=True, right_on="movieId")
# Out:
#         similar       all      score  movieId
# 17067  1.000000  0.040459  24.716368    89745  \
# 20513  0.103711  0.005289  19.610199   106072
# 25058  0.241054  0.012367  19.491770   122892
# 19678  0.216534  0.012119  17.867419   102125
# 16725  0.215043  0.012052  17.843074    88140
# ...         ...       ...        ...      ...
# 292    0.288933  0.288146   1.002730      296
# 585    0.222830  0.228665   0.974483      593
# 522    0.199967  0.217833   0.917984      527
# 1164   0.100895  0.120244   0.839081     1193
# 2766   0.139993  0.169679   0.825051     2858
#
#                                            title
# 17067                       Avengers, The (2012)  \
# 20513                Thor: The Dark World (2013)
# 25058             Avengers: Age of Ultron (2015)
# 19678                          Iron Man 3 (2013)
# 16725  Captain America: The First Avenger (2011)
# ...                                          ...
# 292                          Pulp Fiction (1994)
# 585             Silence of the Lambs, The (1991)
# 522                      Schindler's List (1993)
# 1164      One Flew Over the Cuckoo's Nest (1975)
# 2766                      American Beauty (1999)
#
#                                      genres    year
# 17067          Action|Adventure|Sci-Fi|IMAX  2012.0  \
# 20513         Action|Adventure|Fantasy|IMAX  2013.0
# 25058               Action|Adventure|Sci-Fi  2015.0
# 19678           Action|Sci-Fi|Thriller|IMAX  2013.0
# 16725  Action|Adventure|Sci-Fi|Thriller|War  2011.0
# ...                                     ...     ...
# 292             Comedy|Crime|Drama|Thriller  1994.0
# 585                   Crime|Horror|Thriller  1991.0
# 522                               Drama|War  1993.0
# 1164                                  Drama  1975.0
# 2766                          Drama|Romance  1999.0
#
#                                   clean_title
# 17067                       Avengers The 2012
# 20513                Thor The Dark World 2013
# 25058             Avengers Age of Ultron 2015
# 19678                         Iron Man 3 2013
# 16725  Captain America The First Avenger 2011
# ...                                       ...
# 292                         Pulp Fiction 1994
# 585             Silence of the Lambs The 1991
# 522                      Schindlers List 1993
# 1164      One Flew Over the Cuckoos Nest 1975
# 2766                     American Beauty 1999
#
# [193 rows x 8 columns]

# %% [markdown]
# 25. Defining a function to find similar movies based on a given movie ID:
#
# This function identifies similar users who have rated a movie. It then calculates the recommendation percentages for each movie by similar users and all users, calculates a score based on the proportion of similar user recommendations to all user recommendations, and sorts the movies based on the score to provide the top 10 similar movies with their titles and genres.

# %%
def find_similar_movies(movie_id):
    similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] > 4)]["userId"].unique()
    similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]
    similar_user_recs = similar_user_recs.value_counts() / len(similar_users)

    similar_user_recs = similar_user_recs[similar_user_recs > .10]
    all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
    all_user_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())
    rec_percentages = pd.concat([similar_user_recs, all_user_recs], axis=1)
    rec_percentages.columns = ["similar", "all"]
    
    rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
    rec_percentages = rec_percentages.sort_values("score", ascending=False)
    return rec_percentages.head(10).merge(movies, left_index=True, right_on="movieId")[["score", "title", "genres"]]

# %% [markdown]
# 26. Creating an input widget for the user to enter a movie title:

# %%
movie_name_input = widgets.Text(
    placeholder='Input Movie',
    description='Movie Title:',
    disabled=False
)
recommendation_list = widgets.Output()

def on_type(data):
    with recommendation_list:
        recommendation_list.clear_output()
        title = data["new"]
        if len(title) > 0:
            results = search(title)
            movie_id = results.iloc[0]["movieId"]
            display(find_similar_movies(movie_id))

movie_name_input.observe(on_type, names='value')

display(movie_name_input, recommendation_list)
# Out:
# Text(value='', description='Movie Title:', placeholder='Input Movie')
# Output()

# %% [markdown]
# 27. Merging movies and ratings

# %%
df = pd.merge(movies, ratings, on='movieId')
df = df.drop(['title'], axis=1)
df = df.rename(columns={'clean_title': 'title'})



df
# Out:
#           movieId                                       genres    year
# 0               1  Adventure|Animation|Children|Comedy|Fantasy  1995.0  \
# 1               1  Adventure|Animation|Children|Comedy|Fantasy  1995.0
# 2               1  Adventure|Animation|Children|Comedy|Fantasy  1995.0
# 3               1  Adventure|Animation|Children|Comedy|Fantasy  1995.0
# 4               1  Adventure|Animation|Children|Comedy|Fantasy  1995.0
# ...           ...                                          ...     ...
# 25000090   209157                                        Drama  2018.0
# 25000091   209159                                  Documentary  2001.0
# 25000092   209163                                 Comedy|Drama  2018.0
# 25000093   209169                           (no genres listed)  2001.0
# 25000094   209171                       Action|Adventure|Drama  1962.0
#
#                                 title  userId  rating
# 0                      Toy Story 1995       2     3.5
# 1                      Toy Story 1995       3     4.0
# 2                      Toy Story 1995       4     3.0
# 3                      Toy Story 1995       5     4.0
# 4                      Toy Story 1995       8     4.0
# ...                               ...     ...     ...
# 25000090                      We 2018  119571     1.5
# 25000091      Window of the Soul 2001  115835     3.0
# 25000092               Bad Poems 2018    6964     4.5
# 25000093            A Girl Thing 2001  119571     3.0
# 25000094  Women of Devils Island 1962  119571     3.0
#
# [25000095 rows x 6 columns]

# %%
df2 = df.groupby(['movieId', 'title', 'genres', 'year'])['rating'].mean().reset_index()



df2
# Out:
#        movieId                             title
# 0            1                    Toy Story 1995  \
# 1            2                      Jumanji 1995
# 2            3             Grumpier Old Men 1995
# 3            4            Waiting to Exhale 1995
# 4            5  Father of the Bride Part II 1995
# ...        ...                               ...
# 58670   209157                           We 2018
# 58671   209159           Window of the Soul 2001
# 58672   209163                    Bad Poems 2018
# 58673   209169                 A Girl Thing 2001
# 58674   209171       Women of Devils Island 1962
#
#                                             genres    year    rating
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995.0  3.893708
# 1                       Adventure|Children|Fantasy  1995.0  3.251527
# 2                                   Comedy|Romance  1995.0  3.142028
# 3                             Comedy|Drama|Romance  1995.0  2.853547
# 4                                           Comedy  1995.0  3.058434
# ...                                            ...     ...       ...
# 58670                                        Drama  2018.0  1.500000
# 58671                                  Documentary  2001.0  3.000000
# 58672                                 Comedy|Drama  2018.0  4.500000
# 58673                           (no genres listed)  2001.0  3.000000
# 58674                       Action|Adventure|Drama  1962.0  3.000000
#
# [58675 rows x 5 columns]

# %% [markdown]
# 28. Splitting the "genres" column into three separate columns

# %%
df2['genres'] = df2['genres'].str.split('|')
df2['genres1'] = df2['genres'].str[0].str.strip()
df2['genres2'] = df2['genres'].str[1].str.strip()
df2['genres3'] = df2['genres'].str[2].str.strip()

df3 = df2[['movieId', 'title', 'year', 'rating', 'genres1', 'genres2', 'genres3']]

df3
# Out:
#        movieId                             title    year    rating
# 0            1                    Toy Story 1995  1995.0  3.893708  \
# 1            2                      Jumanji 1995  1995.0  3.251527
# 2            3             Grumpier Old Men 1995  1995.0  3.142028
# 3            4            Waiting to Exhale 1995  1995.0  2.853547
# 4            5  Father of the Bride Part II 1995  1995.0  3.058434
# ...        ...                               ...     ...       ...
# 58670   209157                           We 2018  2018.0  1.500000
# 58671   209159           Window of the Soul 2001  2001.0  3.000000
# 58672   209163                    Bad Poems 2018  2018.0  4.500000
# 58673   209169                 A Girl Thing 2001  2001.0  3.000000
# 58674   209171       Women of Devils Island 1962  1962.0  3.000000
#
#                   genres1    genres2   genres3
# 0               Adventure  Animation  Children
# 1               Adventure   Children   Fantasy
# 2                  Comedy    Romance       NaN
# 3                  Comedy      Drama   Romance
# 4                  Comedy        NaN       NaN
# ...                   ...        ...       ...
# 58670               Drama        NaN       NaN
# 58671         Documentary        NaN       NaN
# 58672              Comedy      Drama       NaN
# 58673  (no genres listed)        NaN       NaN
# 58674              Action  Adventure     Drama
#
# [58675 rows x 7 columns]

# %% [markdown]
# 29. Extracting the data frame

# %%
path = os.path.expanduser('~/Desktop/IRONHACK/Projects/Final-Project/data')
os.makedirs(path, exist_ok=True)

df3.to_csv(os.path.join(path, 'df3.csv'), index=False)
